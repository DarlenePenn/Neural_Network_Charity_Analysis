# %%
# Import our dependencies
import pandas as pd
import matplotlib as plt
from sklearn.datasets import make_blobs
import sklearn as skl
import tensorflow as tf

# %%
# Generate dummy dataset
X, y = make_blobs(n_samples=1000, centers=2, n_features=2, random_state=78)

# Creating a DataFrame with the dummy dataSet
df = pd.DataFrame(X, columns=["Feature 1", "Feature 2"])
df["Target"] = y

# Plotting the dummy data
df.plot.scatter(x="Feature 1", y="Feature 2", c="Target", colormap="winter")
# Out:
# <AxesSubplot:xlabel='Feature 1', ylabel='Feature 2'>

# %%
# Use sklearn to split dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create scaler instance
X_scaler = skl.preprocessing.StandardScaler()

# Fit the scaler
X_scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create the Keras Sequential model
nn_model = tf.keras.models.Sequential()

# %%
# Add our first Dense layer, including the input layer
nn_model.add(tf.keras.layers.Dense(units=1, activation="relu", input_dim=2))

# %%
# Add the output layer that uses a probability activation function
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# %%
# Check the structure of the Sequential model
nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 3
#
#  dense_1 (Dense)             (None, 1)                 2
#
# =================================================================
# Total params: 5
# Trainable params: 5
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Fit the model to the training data
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 3s 784us/step - loss: 0.6431 - accuracy: 0.6787
# Epoch 2/100
# 24/24 [==============================] - 0s 953us/step - loss: 0.6344 - accuracy: 0.6907
# Epoch 3/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6251 - accuracy: 0.7080
# Epoch 4/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6157 - accuracy: 0.7227
# Epoch 5/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6058 - accuracy: 0.7427
# Epoch 6/100
# 24/24 [==============================] - 0s 910us/step - loss: 0.5956 - accuracy: 0.7507
# Epoch 7/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5849 - accuracy: 0.7640
# Epoch 8/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5740 - accuracy: 0.7773
# Epoch 9/100
# 24/24 [==============================] - 0s 997us/step - loss: 0.5632 - accuracy: 0.7907
# Epoch 10/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5522 - accuracy: 0.8027
# Epoch 11/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5411 - accuracy: 0.8147
# Epoch 12/100
# 24/24 [==============================] - 0s 910us/step - loss: 0.5300 - accuracy: 0.8187
# Epoch 13/100
# 24/24 [==============================] - 0s 867us/step - loss: 0.5189 - accuracy: 0.8253
# Epoch 14/100
# 24/24 [==============================] - 0s 910us/step - loss: 0.5078 - accuracy: 0.8347
# Epoch 15/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4973 - accuracy: 0.8467
# Epoch 16/100
# 24/24 [==============================] - 0s 823us/step - loss: 0.4864 - accuracy: 0.8533
# Epoch 17/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4760 - accuracy: 0.8653
# Epoch 18/100
# 24/24 [==============================] - 0s 780us/step - loss: 0.4657 - accuracy: 0.8720
# Epoch 19/100
# 24/24 [==============================] - 0s 953us/step - loss: 0.4555 - accuracy: 0.8800
# Epoch 20/100
# 24/24 [==============================] - 0s 882us/step - loss: 0.4456 - accuracy: 0.8827
# Epoch 21/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4359 - accuracy: 0.8867
# Epoch 22/100
# 24/24 [==============================] - 0s 910us/step - loss: 0.4264 - accuracy: 0.8880
# Epoch 23/100
# 24/24 [==============================] - 0s 823us/step - loss: 0.4171 - accuracy: 0.8947
# Epoch 24/100
# 24/24 [==============================] - 0s 867us/step - loss: 0.4081 - accuracy: 0.8960
# Epoch 25/100
# 24/24 [==============================] - 0s 997us/step - loss: 0.3994 - accuracy: 0.9013
# Epoch 26/100
# 24/24 [==============================] - 0s 780us/step - loss: 0.3908 - accuracy: 0.9027
# Epoch 27/100
# 24/24 [==============================] - 0s 867us/step - loss: 0.3823 - accuracy: 0.9067
# Epoch 28/100
# 24/24 [==============================] - 0s 867us/step - loss: 0.3741 - accuracy: 0.9120
# Epoch 29/100
# 24/24 [==============================] - 0s 780us/step - loss: 0.3660 - accuracy: 0.9173
# Epoch 30/100
# 24/24 [==============================] - 0s 997us/step - loss: 0.3580 - accuracy: 0.9227
# Epoch 31/100
# 24/24 [==============================] - 0s 780us/step - loss: 0.3503 - accuracy: 0.9253
# Epoch 32/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3427 - accuracy: 0.9280
# Epoch 33/100
# 24/24 [==============================] - 0s 803us/step - loss: 0.3352 - accuracy: 0.9320
# Epoch 34/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3278 - accuracy: 0.9360
# Epoch 35/100
# 24/24 [==============================] - 0s 823us/step - loss: 0.3204 - accuracy: 0.9360
# Epoch 36/100
# 24/24 [==============================] - 0s 953us/step - loss: 0.3133 - accuracy: 0.9413
# Epoch 37/100
# 24/24 [==============================] - 0s 823us/step - loss: 0.3062 - accuracy: 0.9453
# Epoch 38/100
# 24/24 [==============================] - 0s 823us/step - loss: 0.2992 - accuracy: 0.9480
# Epoch 39/100
# 24/24 [==============================] - 0s 953us/step - loss: 0.2924 - accuracy: 0.9507
# Epoch 40/100
# 24/24 [==============================] - 0s 865us/step - loss: 0.2857 - accuracy: 0.9507
# Epoch 41/100
# 24/24 [==============================] - 0s 953us/step - loss: 0.2792 - accuracy: 0.9520
# Epoch 42/100
# 24/24 [==============================] - 0s 867us/step - loss: 0.2729 - accuracy: 0.9547
# Epoch 43/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2667 - accuracy: 0.9560
# Epoch 44/100
# 24/24 [==============================] - 0s 868us/step - loss: 0.2606 - accuracy: 0.9587
# Epoch 45/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2547 - accuracy: 0.9627
# Epoch 46/100
# 24/24 [==============================] - 0s 823us/step - loss: 0.2489 - accuracy: 0.9627
# Epoch 47/100
# 24/24 [==============================] - 0s 867us/step - loss: 0.2432 - accuracy: 0.9653
# Epoch 48/100
# 24/24 [==============================] - 0s 953us/step - loss: 0.2378 - accuracy: 0.9667
# Epoch 49/100
# 24/24 [==============================] - 0s 997us/step - loss: 0.2324 - accuracy: 0.9667
# Epoch 50/100
# 24/24 [==============================] - 0s 953us/step - loss: 0.2272 - accuracy: 0.9693
# Epoch 51/100
# 24/24 [==============================] - 0s 953us/step - loss: 0.2222 - accuracy: 0.9707
# Epoch 52/100
# 24/24 [==============================] - 0s 779us/step - loss: 0.2172 - accuracy: 0.9720
# Epoch 53/100
# 24/24 [==============================] - 0s 910us/step - loss: 0.2123 - accuracy: 0.9747
# Epoch 54/100
# 24/24 [==============================] - 0s 997us/step - loss: 0.2074 - accuracy: 0.9760
# Epoch 55/100
# 24/24 [==============================] - 0s 737us/step - loss: 0.2026 - accuracy: 0.9800
# Epoch 56/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1981 - accuracy: 0.9800
# Epoch 57/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1936 - accuracy: 0.9813
# Epoch 58/100
# 24/24 [==============================] - 0s 780us/step - loss: 0.1892 - accuracy: 0.9813
# Epoch 59/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1850 - accuracy: 0.9827
# Epoch 60/100
# 24/24 [==============================] - 0s 780us/step - loss: 0.1808 - accuracy: 0.9840
# Epoch 61/100
# 24/24 [==============================] - 0s 910us/step - loss: 0.1766 - accuracy: 0.9840
# Epoch 62/100
# 24/24 [==============================] - 0s 780us/step - loss: 0.1727 - accuracy: 0.9853
# Epoch 63/100
# 24/24 [==============================] - 0s 997us/step - loss: 0.1688 - accuracy: 0.9853
# Epoch 64/100
# 24/24 [==============================] - 0s 780us/step - loss: 0.1650 - accuracy: 0.9853
# Epoch 65/100
# 24/24 [==============================] - 0s 910us/step - loss: 0.1613 - accuracy: 0.9853
# Epoch 66/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1578 - accuracy: 0.9867
# Epoch 67/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1542 - accuracy: 0.9867
# Epoch 68/100
# 24/24 [==============================] - 0s 823us/step - loss: 0.1509 - accuracy: 0.9867
# Epoch 69/100
# 24/24 [==============================] - 0s 953us/step - loss: 0.1475 - accuracy: 0.9880
# Epoch 70/100
# 24/24 [==============================] - 0s 953us/step - loss: 0.1443 - accuracy: 0.9880
# Epoch 71/100
# 24/24 [==============================] - 0s 823us/step - loss: 0.1412 - accuracy: 0.9880
# Epoch 72/100
# 24/24 [==============================] - 0s 910us/step - loss: 0.1382 - accuracy: 0.9893
# Epoch 73/100
# 24/24 [==============================] - 0s 823us/step - loss: 0.1352 - accuracy: 0.9907
# Epoch 74/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1324 - accuracy: 0.9907
# Epoch 75/100
# 24/24 [==============================] - 0s 910us/step - loss: 0.1296 - accuracy: 0.9920
# Epoch 76/100
# 24/24 [==============================] - 0s 954us/step - loss: 0.1269 - accuracy: 0.9920
# Epoch 77/100
# 24/24 [==============================] - 0s 823us/step - loss: 0.1242 - accuracy: 0.9920
# Epoch 78/100
# 24/24 [==============================] - 0s 953us/step - loss: 0.1217 - accuracy: 0.9947
# Epoch 79/100
# 24/24 [==============================] - 0s 953us/step - loss: 0.1192 - accuracy: 0.9947
# Epoch 80/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1168 - accuracy: 0.9960
# Epoch 81/100
# 24/24 [==============================] - 0s 823us/step - loss: 0.1144 - accuracy: 0.9960
# Epoch 82/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1121 - accuracy: 0.9960
# Epoch 83/100
# 24/24 [==============================] - 0s 780us/step - loss: 0.1100 - accuracy: 0.9973
# Epoch 84/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1078 - accuracy: 0.9973
# Epoch 85/100
# 24/24 [==============================] - 0s 867us/step - loss: 0.1057 - accuracy: 0.9973
# Epoch 86/100
# 24/24 [==============================] - 0s 910us/step - loss: 0.1037 - accuracy: 0.9973
# Epoch 87/100
# 24/24 [==============================] - 0s 953us/step - loss: 0.1017 - accuracy: 0.9973
# Epoch 88/100
# 24/24 [==============================] - 0s 823us/step - loss: 0.0998 - accuracy: 0.9973
# Epoch 89/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0980 - accuracy: 0.9987
# Epoch 90/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0962 - accuracy: 0.9987
# Epoch 91/100
# 24/24 [==============================] - 0s 953us/step - loss: 0.0944 - accuracy: 1.0000
# Epoch 92/100
# 24/24 [==============================] - 0s 867us/step - loss: 0.0927 - accuracy: 1.0000
# Epoch 93/100
# 24/24 [==============================] - 0s 867us/step - loss: 0.0910 - accuracy: 1.0000
# Epoch 94/100
# 24/24 [==============================] - 0s 867us/step - loss: 0.0894 - accuracy: 1.0000
# Epoch 95/100
# 24/24 [==============================] - 0s 737us/step - loss: 0.0878 - accuracy: 1.0000
# Epoch 96/100
# 24/24 [==============================] - 0s 997us/step - loss: 0.0863 - accuracy: 1.0000
# Epoch 97/100
# 24/24 [==============================] - 0s 823us/step - loss: 0.0847 - accuracy: 1.0000
# Epoch 98/100
# 24/24 [==============================] - 0s 823us/step - loss: 0.0833 - accuracy: 1.0000
# Epoch 99/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0819 - accuracy: 1.0000
# Epoch 100/100
# 24/24 [==============================] - 0s 737us/step - loss: 0.0804 - accuracy: 1.0000

# %%
# Create a DataFrame containing training history
history_df = pd.DataFrame(fit_model.history, index=range(1,len(fit_model.history["loss"])+1))

# Plot the loss
history_df.plot(y="loss")
# Out:
# <AxesSubplot:>

# %%
# Plot the accuracy
history_df.plot(y="accuracy")
# Out:
# <AxesSubplot:>

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 8/8 - 3s - loss: 0.0744 - accuracy: 1.0000 - 3s/epoch - 315ms/step
# Loss: 0.07437550276517868, Accuracy: 1.0

# %%
# Predict the classification of a new set of blob data
new_X, new_Y = make_blobs(n_samples=10, centers=2, n_features=2, random_state=78)
new_X_scaled = X_scaler.transform(new_X)
(nn_model.predict(new_X_scaled) > 0.5).astype("int32")
# Out:
# array([[0],
#        [1],
#        [0],
#        [1],
#        [0],
#        [0],
#        [1],
#        [1],
#        [1],
#        [0]])

# %%
from sklearn.datasets import make_moons

# Creating dummy nonlinear data
X_moons, y_moons = make_moons(n_samples=1000, noise=0.08, random_state=78)

# Transforming y_moons to a vertical vector
y_moons = y_moons.reshape(-1, 1)

# Creating a DataFrame to plot the nonlinear dummy data
df_moons = pd.DataFrame(X_moons, columns=["Feature 1", "Feature 2"])
df_moons["Target"] = y_moons

# Plot the nonlinear dummy data
df_moons.plot.scatter(x="Feature 1",y="Feature 2", c="Target",colormap="winter")
# Out:
# <AxesSubplot:xlabel='Feature 1', ylabel='Feature 2'>
